# %% [markdown]
# # Generar una matriz A que tenga 300x300 que dentro tiene numeros aleatorios de 0 a 218.

# %%
import random as rd

# %% [markdown]
# ### Compression list
# ### i=columnas, j=filas

# %% [markdown]
# ### casteamos a int, para poder redimensionar las matrices

# %%
fila_a = int(input("Ingrese las fila de la matriz A:"))
# Out:
# Ingrese las fila de la matriz A: 300

# %%
columna_a = int(input("Ingrese las columnas de la matriz A:"))
# Out:
# Ingrese las columnas de la matriz A: 300

# %%
A = [[rd.randint(0,219) for i in range(columna_a)] for j in range(fila_a)]

# %%
fila_b = int(input("Ingrese las filas de la matriz B:"))
# Out:
# Ingrese las filas de la matriz B: 300

# %%
columna_b = int(input("Ingrese las columnas de la matriz B:"))
# Out:
# Ingrese las columnas de la matriz B: 300

# %%
B = [[rd.randint(0,219) for i in range(columna_b)] for j in range(fila_b)]

# %% [markdown]
# ### validar que las matrices se pueden multiplicar

# %%
if(len(A[0]) == len(B)):
    #meter la multiplicacion
    print("Se pueden multiplicar")
else:
    print("No se pueden multiplicar, vuelve a meter dimensiones")
# Out:
# Se pueden multiplicar

# %%
print('Las nuevas dimensiones introducidas de la matriz A son: ' + str(fila_a) + "x"+ str(columna_a))
print('Las nuevas dimensiones introducidas de la matriz A son: ' + str(fila_b) + "x"+ str(columna_b))
# Out:
# Las nuevas dimensiones introducidas de la matriz A son: 300x300
# Las nuevas dimensiones introducidas de la matriz A son: 300x300

# %% [markdown]
# ## Multiplicamos:

# %%
def mult_matrices(m_A,m_B):
    fila_a = len(m_A)
    columna_a = len(m_A[0])
    columna_b = len(m_B[0])
    C = [[0 for _ in range(columna_b)]for _ in range(fila_a)]
    
    for i in range (fila_a):
        for j in range (columna_b):
            for k in range (columna_a):
                C[i][j] += m_A[i][k] * m_B[k][j]
    print(C)

# %%
mult_matrices(A,B)
# Out:
# [[3520778, 3638583, 3544532, 3476994, 3286988, 3588667, 3672307, 3592628, 3725825, 3639063, 3500105, 3481284, 3345638, 3588092, 3340336, 3525967, 3620603, 3698215, 3374359, 3691468, 3718168, 3722817, 3664246, 3613840, 3644559, 3191180, 3624064, 3597316, 3248332, 3379821, 3456522, 3479920, 3684586, 3788649, 3637035, 3541077, 3554404, 3435078, 3543644, 3513420, 3545611, 3434508, 3759540, 3465785, 3419386, 3455431, 3554735, 3531849, 3667298, 3302581, 3437643, 3554304, 3240282, 3366070, 3465611, 3175160, 3537001, 3274501, 3431905, 3571120, 3242814, 3544812, 3659757, 3316286, 3714380, 3559098, 3420343, 3659795, 3464991, 3543021, 3542030, 3614720, 3719204, 3405489, 3305746, 3510717, 3659060, 3538033, 3312573, 3584309, 3661020, 3652800, 3647012, 3535513, 3654058, 3686622, 3312949, 3428410, 3461820, 3491142, 3293036, 3535525, 3286550, 3431679, 3524400, 3506904, 3553897, 3416197, 3596578, 3520363, 3516317, 3384549, 3486093, 3455428, 3668266, 3592374, 3357003, 3520246, 3548167, 3509384, 3481879, 3410950, 3537430, 3514426, 3795126, 3304471, 3360713, 3762526, 3430667, 3499658, 3431470, 3374001, 3309722, 3664220, 3501279, 3491789, 3578217, 3574082, 3347256, 3